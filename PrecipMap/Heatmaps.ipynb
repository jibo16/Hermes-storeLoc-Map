# %%
import pandas as pd
import os
import folium

# %%
folder = '/home/jibo16/Desktop/Hermes-storeLoc-Map/PrecipMap/Datak/7890488'

filelist = [file for file in os.listdir(folder) if file.endswith('csv')]


for file in filelist:
    '''
    This iteration converts csv's to df's and gives the df the same name as the csv file
    '''
    exec("%s = pd.read_csv('%s',on_bad_lines='skip')" % (file.split('.')[0], os.path.join(folder,file)))

# %%
USW00014929.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# tmax          551
# tmin          587
# prcp          687
# dtype: int64

# %%
USW00014925.isna().sum()
# Out:
# Unnamed: 0        0
# Date              0
# tmax           9558
# tmin           9590
# prcp          10109
# dtype: int64

# %%
for file in filelist:
    exec("print(file)")
# Out:
# city_info.csv
# USW00094973.csv
# USW00094950.csv
# USW00094949.csv
# USW00094929.csv
# USW00094910.csv
# USW00094908.csv
# USW00094860.csv
# USW00094850.csv
# USW00094847.csv
# USW00094846.csv
# USW00094830.csv
# USW00094823.csv
# USW00094822.csv
# USW00094815.csv
# USW00094746.csv
# USW00094728.csv
# USW00094298.csv
# USW00094236.csv
# USW00094224.csv
# USW00094129.csv
# USW00094040.csv
# USW00094014.csv
# USW00094012.csv
# USW00094008.csv
# USW00093988.csv
# USW00093874.csv
# USW00093842.csv
# USW00093824.csv
# USW00093822.csv
# USW00093821.csv
# USW00093820.csv
# USW00093819.csv
# USW00093817.csv
# USW00093815.csv
# USW00093812.csv
# USW00093805.csv
# USW00093729.csv
# USW00093721.csv
# USW00093193.csv
# USW00093134.csv
# USW00093058.csv
# USW00093037.csv
# USW00053920.csv
# USW00024286.csv
# USW00024257.csv
# USW00024233.csv
# USW00024232.csv
# USW00024221.csv
# USW00024213.csv
# USW00024163.csv
# USW00024157.csv
# USW00024155.csv
# USW00024153.csv
# USW00024149.csv
# ...

# %%
sheets=[]    
for var in dir():
    if isinstance(locals()[var], pd.core.frame.DataFrame):
        print(locals()[var])
# Out:
#        Unnamed: 0        Date  tmax  tmin  prcp
# 0               1  1894-01-01  60.0  41.0  0.00
# 1               2  1894-01-02  58.0  50.0  0.40
# 2               3  1894-01-03  57.0  42.0  0.00
# 3               4  1894-01-04  53.0  42.0  0.28
# 4               5  1894-01-05  50.0  38.0  0.00
# ...           ...         ...   ...   ...   ...
# 46746       46747  2021-12-27   NaN   NaN   NaN
# 46747       46748  2021-12-28   NaN   NaN   NaN
# 46748       46749  2021-12-29   NaN   NaN   NaN
# 46749       46750  2021-12-30   NaN   NaN   NaN
# 46750       46751  2021-12-31   NaN   NaN   NaN
#
# [46751 rows x 5 columns]
#        Unnamed: 0        Date  tmax  tmin  prcp
# 0               1  1894-01-01  63.0  31.0  0.00
# 1               2  1894-01-02  70.0  36.0  0.00
# 2               3  1894-01-03  71.0  42.0  0.00
# 3               4  1894-01-04  74.0  44.0  0.23
# 4               5  1894-01-05  76.0  52.0  0.57
# ...           ...         ...   ...   ...   ...
# ...

# %%
def NewCol(x):
    x['id'] = "{}".format(x) 
    return x

# %%
USC00042863

# %%
USW00014929.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# tmax          551
# tmin          587
# prcp          687
# dtype: int64

# %%
USW00014925.isna().sum()
# Out:
# Unnamed: 0        0
# Date              0
# tmax           9558
# tmin           9590
# prcp          10109
# dtype: int64

# %%
for file in sheets:
    exec('file = file.dropna()')

# %%
# %whos
# Out:
# Variable      Type         Data/Info
# ------------------------------------
# NewCol        function     <function NewCol at 0x7fd22ea76c10>
# USC00042863   DataFrame           Unnamed: 0        <...>n[46751 rows x 5 columns]
# USC00166584   DataFrame           Unnamed: 0        <...>n[46751 rows x 5 columns]
# USC00280734   DataFrame           Unnamed: 0        <...>n[47116 rows x 5 columns]
# USC00286055   DataFrame           Unnamed: 0        <...>n[47116 rows x 5 columns]
# USC00356749   DataFrame           Unnamed: 0        <...>n[53691 rows x 5 columns]
# USC00380072   DataFrame           Unnamed: 0        <...>n[47116 rows x 5 columns]
# USW00003017   DataFrame           Unnamed: 0        <...>n[54787 rows x 5 columns]
# USW00003103   DataFrame           Unnamed: 0        <...>n[44925 rows x 5 columns]
# USW00003145   DataFrame           Unnamed: 0        <...>n[53326 rows x 5 columns]
# USW00003171   DataFrame           Unnamed: 0        <...>n[47116 rows x 5 columns]
# ...

# %%
city_info
