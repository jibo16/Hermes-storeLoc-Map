# %%
import pandas as pd
import os
import folium

# %%
folder = '/home/jibo16/Desktop/Hermes-storeLoc-Map/PrecipMap/Datak/7890488'

filelist = [file for file in os.listdir(folder) if file.endswith('csv')]


for file in filelist:
    '''
    Lectura de archivos csv y nombrandolos automaticamente, por lo que los datasets son importados sin nombrarlos
    individualmente
    '''
    exec("%s = pd.read_csv('%s',on_bad_lines='skip')" % (file.split('.')[0], os.path.join(folder,file)))

# %%
for file in filelist:
    exec("print(file)")
# Out:
# city_info.csv
# USW00094973.csv
# USW00094950.csv
# USW00094949.csv
# USW00094929.csv
# USW00094910.csv
# USW00094908.csv
# USW00094860.csv
# USW00094850.csv
# USW00094847.csv
# USW00094846.csv
# USW00094830.csv
# USW00094823.csv
# USW00094822.csv
# USW00094815.csv
# USW00094746.csv
# USW00094728.csv
# USW00094298.csv
# USW00094236.csv
# USW00094224.csv
# USW00094129.csv
# USW00094040.csv
# USW00094014.csv
# USW00094012.csv
# USW00094008.csv
# USW00093988.csv
# USW00093874.csv
# USW00093842.csv
# USW00093824.csv
# USW00093822.csv
# USW00093821.csv
# USW00093820.csv
# USW00093819.csv
# USW00093817.csv
# USW00093815.csv
# USW00093812.csv
# USW00093805.csv
# USW00093729.csv
# USW00093721.csv
# USW00093193.csv
# USW00093134.csv
# USW00093058.csv
# USW00093037.csv
# USW00053920.csv
# USW00024286.csv
# USW00024257.csv
# USW00024233.csv
# USW00024232.csv
# USW00024221.csv
# USW00024213.csv
# USW00024163.csv
# USW00024157.csv
# USW00024155.csv
# USW00024153.csv
# USW00024149.csv
# USW00024144.csv
# USW00024143.csv
# USW00024131.csv
# USW00024128.csv
# USW00024127.csv
# USW00024121.csv
# USW00024032.csv
# USW00024028.csv
# USW00024023.csv
# USW00024021.csv
# USW00024018.csv
# USW00024011.csv
# USW00023275.csv
# USW00023271.csv
# USW00023188.csv
# USW00023185.csv
# USW00023183.csv
# USW00023179.csv
# USW00023160.csv
# USW00023155.csv
# USW00023154.csv
# USW00023066.csv
# USW00023065.csv
# USW00023051.csv
# USW00023050.csv
# USW00023047.csv
# USW00023044.csv
# USW00023009.csv
# USW00014991.csv
# USW00014990.csv
# USW00014972.csv
# USW00014944.csv
# USW00014943.csv
# USW00014942.csv
# USW00014941.csv
# USW00014939.csv
# USW00014936.csv
# USW00014935.csv
# USW00014933.csv
# USW00014929.csv
# USW00014926.csv
# USW00014925.csv
# USW00014923.csv
# USW00014922.csv
# USW00014920.csv
# USW00014918.csv
# USW00014916.csv
# USW00014914.csv
# USW00014913.csv
# USW00014898.csv
# USW00014897.csv
# USW00014895.csv
# USW00014894.csv
# USW00014860.csv
# USW00014848.csv
# USW00014847.csv
# USW00014845.csv
# USW00014842.csv
# USW00014840.csv
# USW00014839.csv
# USW00014837.csv
# USW00014836.csv
# USW00014827.csv
# USW00014821.csv
# USW00014792.csv
# USW00014778.csv
# USW00014768.csv
# USW00014764.csv
# USW00014753.csv
# USW00014750.csv
# USW00014745.csv
# USW00014742.csv
# USW00014739.csv
# USW00014735.csv
# USW00014733.csv
# USW00014711.csv
# USW00014710.csv
# USW00013996.csv
# USW00013995.csv
# USW00013994.csv
# USW00013985.csv
# USW00013984.csv
# USW00013971.csv
# USW00013970.csv
# USW00013968.csv
# USW00013967.csv
# USW00013964.csv
# USW00013963.csv
# USW00013962.csv
# USW00013958.csv
# USW00013957.csv
# USW00013942.csv
# USW00013899.csv
# USW00013897.csv
# USW00013896.csv
# USW00013895.csv
# USW00013893.csv
# USW00013889.csv
# USW00013886.csv
# USW00013883.csv
# USW00013882.csv
# USW00013881.csv
# USW00013876.csv
# USW00013874.csv
# USW00013873.csv
# USW00013866.csv
# USW00013865.csv
# USW00013838.csv
# USW00013833.csv
# USW00013781.csv
# USW00013743.csv
# USW00013740.csv
# USW00013739.csv
# USW00013737.csv
# USW00013736.csv
# USW00013733.csv
# USW00013722.csv
# USW00012960.csv
# USW00012924.csv
# USW00012923.csv
# USW00012921.csv
# USW00012844.csv
# USW00012842.csv
# USW00012839.csv
# USW00012836.csv
# USW00012835.csv
# USW00012816.csv
# USW00012815.csv
# USW00004853.csv
# USW00003965.csv
# USW00003963.csv
# USW00003953.csv
# USW00003947.csv
# USW00003945.csv
# USW00003940.csv
# USW00003937.csv
# USW00003927.csv
# USW00003904.csv
# USW00003872.csv
# USW00003860.csv
# USW00003859.csv
# USW00003856.csv
# USW00003822.csv
# USW00003820.csv
# USW00003813.csv
# USW00003812.csv
# USW00003171.csv
# USW00003145.csv
# USW00003103.csv
# USW00003017.csv
# USC00380072.csv
# USC00356749.csv
# USC00286055.csv
# USC00280734.csv
# USC00166584.csv
# USC00042863.csv

# %%
sheets=[]    
for var in dir():
    if isinstance(locals()[var], pd.core.frame.DataFrame):
        sheets.append(var)

# %%
h = 0
h1 = 1
h2 = 2

l = [h,h1,h2]

# %%
l
# Out:
# [0, 1, 2]

# %%
city_info

# %%
for i in sheets:
    CSVSetter(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7275/3007986209.py in <module>
#       1 for i in sheets:
# ----> 2     CSVSetter(i)
#
# /tmp/ipykernel_7275/3812126123.py in CSVSetter(x)
#       1 def CSVSetter(x):
# ----> 2     return x.dropna()
#
# AttributeError: 'str' object has no attribute 'dropna'
